# %%
# !pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.5-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\muhid\anaconda3\lib\site-packages (from scikit-surprise) (1.5.2)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\muhid\anaconda3\lib\site-packages (from scikit-surprise) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\muhid\anaconda3\lib\site-packages (from scikit-surprise) (1.16.3)
# Downloading scikit_surprise-1.1.5-cp313-cp313-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.0/1.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.1 MB/s  0:00:01
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.5

# %%
# Problem: Recommender System with Matrix Factorization
# Dataset: https://www.kaggle.com/datasets/shubhammehta21/movie-lens-small-latest-dataset

import pandas as pd
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import SVD
from surprise.model_selection import cross_validate
from surprise import accuracy

# %%
# Step 1: Load the MovieLens dataset.
ratings = pd.read_csv('ratings.csv')
print(ratings.head())
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Step 2: Prepare the data for Surprise library.
# print(ratings['rating'].min()) # 0.5
# print(ratings['rating'].max()) # 5.0
# Define the rating scale.
reader = Reader(rating_scale=(ratings['rating'].min(), ratings['rating'].max()))
# Load the data into the Surprise dataset format
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# %%
# Step 3: Split data into train-validation datasets
trainset, valset = train_test_split(data, test_size=0.2)

# %%
# Step 4: Matrix Factorization using (Singular Value Decomposition) SVD
svd = SVD()
# Perform cross validation to evaluate the model
cross_validate(svd, data, measures=['RMSE', 'MSE'], cv=5, verbose=True)

# Output
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8724  0.8690  0.8734  0.8805  0.8733  0.8737  0.0037
# MSE (testset)     0.7611  0.7552  0.7628  0.7752  0.7627  0.7634  0.0065
# Fit time          0.43    0.41    0.40    0.40    0.40    0.41    0.01
# Test time         0.07    0.08    0.08    0.07    0.05    0.07    0.01
